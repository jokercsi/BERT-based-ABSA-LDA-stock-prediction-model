# %%
import pandas as pd

df = pd.read_csv('reuters_headlines.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-66cb49c2780a> in <module>
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('reuters_headlines.csv')
#
# c:\Users\kim\anaconda3\envs\bert\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
# ...

# %%
df
# Out:
#                                                Headlines         Time  \
# 0      TikTok considers London and other locations fo...  Jul 18 2020
# 1      Disney cuts ad spending on Facebook amid growi...  Jul 18 2020
# 2      Trail of missing Wirecard executive leads to B...  Jul 18 2020
# 3      Twitter says attackers downloaded data from up...  Jul 18 2020
# 4      U.S. Republicans seek liability protections as...  Jul 17 2020
# ...                                                  ...          ...
# 32765  Malaysia says never hired British data firm at...  Mar 20 2018
# 32766  Prosecutors search Volkswagen headquarters in ...  Mar 20 2018
# 32767   McDonald's sets greenhouse gas reduction targets  Mar 20 2018
# 32768  Pratt & Whitney to deliver spare A320neo engin...  Mar 20 2018
# 32769  UK will always consider ways to improve data l...  Mar 20 2018
#
#                                              Description
# 0      TikTok has been in discussions with the UK gov...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32770 entries, 0 to 32769
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Headlines    32770 non-null  object
#  1   Time         32770 non-null  object
#  2   Description  32770 non-null  object
# dtypes: object(3)
# memory usage: 768.2+ KB

# %%
df['Time'] = pd.to_datetime(df['Time'], format='%b %d %Y', errors='raise')

# %%
df = df.sort_values(by='Time')

# %%
df
# Out:
#                                                Headlines       Time  \
# 32769  UK will always consider ways to improve data l... 2018-03-20
# 32738  Senate Democrat wants Facebook CEO Zuckerberg ... 2018-03-20
# 32737  Factbox: How United States, others regulate au... 2018-03-20
# 32736  Cambridge Analytica played key Trump campaign ... 2018-03-20
# 32735  Start of AT&T-Time Warner trial delayed until ... 2018-03-20
# ...                                                  ...        ...
# 39     Exclusive: Pact to aid poor cocoa farmers in p... 2020-07-17
# 3      Twitter says attackers downloaded data from up... 2020-07-18
# 2      Trail of missing Wirecard executive leads to B... 2020-07-18
# 1      Disney cuts ad spending on Facebook amid growi... 2020-07-18
# 0      TikTok considers London and other locations fo... 2020-07-18
#
#                                              Description
# 32769  Britain will consider any suggestions to give ...
# ...

# %%
df.reset_index()
# Out:
#        index                                          Headlines       Time  \
# 0      32769  UK will always consider ways to improve data l... 2018-03-20
# 1      32738  Senate Democrat wants Facebook CEO Zuckerberg ... 2018-03-20
# 2      32737  Factbox: How United States, others regulate au... 2018-03-20
# 3      32736  Cambridge Analytica played key Trump campaign ... 2018-03-20
# 4      32735  Start of AT&T-Time Warner trial delayed until ... 2018-03-20
# ...      ...                                                ...        ...
# 32765     39  Exclusive: Pact to aid poor cocoa farmers in p... 2020-07-17
# 32766      3  Twitter says attackers downloaded data from up... 2020-07-18
# 32767      2  Trail of missing Wirecard executive leads to B... 2020-07-18
# 32768      1  Disney cuts ad spending on Facebook amid growi... 2020-07-18
# 32769      0  TikTok considers London and other locations fo... 2020-07-18
#
#                                              Description
# ...

# %%
df.to_csv('reuters_headlines_input.csv',index=False)

# %%
df = pd.read_csv('reuters.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x81 in position 157: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-5-29ef76611e1c> in <module>
# ----> 1 df = pd.read_csv('reuters.csv')
#
# ...
